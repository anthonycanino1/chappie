# %% [markdown]
# Setup

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

import pandas as pd
import numpy as np

# %%
from IPython.display import display, HTML

CSS = """
.output {
    flex-direction: row;
}
"""

HTML('<style>{}</style>'.format(CSS))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %% [markdown]
# Given a set of observation traces, we first need to parse each trace:

# %%
trace = {f.split(r'.')[0]: pd.read_csv(os.path.join('data', f)) for f in os.listdir('data')}

# %% [markdown]
# VM

# %%
display(trace['vm'].head(20))
display(trace['tid'].head(20))
display(trace['activity'].head(20))
# Out:
#     epoch      timestamp             thread  id  state
# 0       1  1565621927794  Reference Handler   2   True
# 1       1  1565621927794          Finalizer   3  False
# 2       1  1565621927794  Signal Dispatcher   4   True
# 3       1  1565621927794               main   1   True
# 4       1  1565621927794          Chaperone  36   True
# 5       1  1565621927794     Common-Cleaner  21  False
# 6       2  1565621927796  Reference Handler   2   True
# 7       2  1565621927796          Finalizer   3  False
# 8       2  1565621927796  Signal Dispatcher   4   True
# 9       2  1565621927796               main   1   True
# 10      2  1565621927796          Chaperone  36   True
# 11      2  1565621927796     Common-Cleaner  21  False
# 12      3  1565621927797  Reference Handler   2   True
# 13      3  1565621927797          Finalizer   3  False
# 14      3  1565621927797  Signal Dispatcher   4   True
# 15      3  1565621927797               main   1   True
# 16      3  1565621927797          Chaperone  36   True
# 17      3  1565621927797     Common-Cleaner  21  False
# 18      4  1565621927798  Reference Handler   2   True
# 19      4  1565621927798          Finalizer   3  False
#       thread   tid
# 0       main  8373
# 1  Chaperone  8461
#     epoch      timestamp     total     state
# 0       1  1565621927794  1.164854  0.064933
# 1       2  1565621927796  1.143821  0.049798
# 2       3  1565621927797  1.168077  0.069164
# 3       4  1565621927798  1.773208  0.999936
# 4       5  1565621927800  1.125044  0.034681
# 5       6  1565621927801  1.158095  0.046836
# 6       7  1565621927802  1.160983  0.048479
# 7       8  1565621927803  1.625238  0.999958
# 8       9  1565621927805  1.121073  0.034696
# 9      10  1565621927806  1.164782  0.066831
# 10     11  1565621927807  1.127684  0.048354
# 11     12  1565621927808  1.501021  0.999945
# 12     13  1565621927810  1.164801  0.048259
# 13     14  1565621927811  1.114063  0.050384
# 14     15  1565621927812  1.142124  0.048693
# 15     16  1565621927813  1.493647  0.999949
# 16     17  1565621927815  1.124120  0.034540
# 17     18  1565621927816  1.139404  0.047158
# 18     19  1565621927817  1.140590  0.048216
# 19     20  1565621927818  1.532112  0.999954

# %% [markdown]
# The vm trace requires three parsing steps:

# %% [markdown]
#     1) Add the thread tid to each record for alignment with os data
#     2) Add a trimmed thread name for alignment with os data that does not have a tid
#     3) Add chappie's fractional activeness
#     4) Normalize the state by epoch -> needs to happen post alignment with os due to os threads

# %%
trace['vm']['tid'] = trace['vm'].thread.map(trace['tid'].set_index('thread').to_dict()['tid']).fillna(-1).astype(int)
trace['vm']['os_thread'] = trace['vm'].thread.str[:15]
trace['vm'].loc[trace['vm'].thread == 'Chaperone', 'state'] = trace['activity'].state
# trace['vm'].state = (trace['vm'].state / trace['vm'].groupby('epoch').state.sum()).fillna(1)

# %%
trace['vm'].head(20)
# Out:
#     epoch      timestamp             thread  id      state   tid  \
# 0       1  1565621927794  Reference Handler   2       True    -1
# 1       1  1565621927794          Finalizer   3      False    -1
# 2       1  1565621927794  Signal Dispatcher   4       True    -1
# 3       1  1565621927794               main   1       True  8373
# 4       1  1565621927794          Chaperone  36  0.0346813  8461
# 5       1  1565621927794     Common-Cleaner  21      False    -1
# 6       2  1565621927796  Reference Handler   2       True    -1
# 7       2  1565621927796          Finalizer   3      False    -1
# 8       2  1565621927796  Signal Dispatcher   4       True    -1
# 9       2  1565621927796               main   1       True  8373
# 10      2  1565621927796          Chaperone  36   0.048354  8461
# 11      2  1565621927796     Common-Cleaner  21      False    -1
# 12      3  1565621927797  Reference Handler   2       True    -1
# 13      3  1565621927797          Finalizer   3      False    -1
# 14      3  1565621927797  Signal Dispatcher   4       True    -1
# 15      3  1565621927797               main   1       True  8373
# 16      3  1565621927797          Chaperone  36  0.0345399  8461
# 17      3  1565621927797     Common-Cleaner  21      False    -1
# 18      4  1565621927798  Reference Handler   2       True    -1
# 19      4  1565621927798          Finalizer   3      False    -1
#
#           os_thread
# 0   Reference Handl
# 1         Finalizer
# 2   Signal Dispatch
# 3              main
# 4         Chaperone
# 5    Common-Cleaner
# 6   Reference Handl
# 7         Finalizer
# 8   Signal Dispatch
# 9              main
# 10        Chaperone
# 11   Common-Cleaner
# 12  Reference Handl
# 13        Finalizer
# 14  Signal Dispatch
# 15             main
# 16        Chaperone
# 17   Common-Cleaner
# 18  Reference Handl
# 19        Finalizer

# %% [markdown]
# OS

# %%
display(trace['os'].head(20))
display(trace['sys'].head(20))
# Out:
#     epoch   tid      timestamp  \
# 0       4  8372  1565621927798
# 1       4  8373  1565621927798
# 2       4  8374  1565621927798
# 3       4  8375  1565621927798
# 4       4  8376  1565621927798
# 5       4  8377  1565621927798
# 6       4  8378  1565621927798
# 7       4  8379  1565621927798
# 8       4  8380  1565621927798
# 9       4  8381  1565621927798
# 10      4  8382  1565621927798
# 11      4  8383  1565621927798
# 12      4  8384  1565621927798
# 13      4  8385  1565621927798
# 14      4  8386  1565621927798
# 15      4  8390  1565621927798
# 16      4  8391  1565621927798
# 17      4  8392  1565621927798
# 18      4  8397  1565621927798
# 19      4  8398  1565621927798
#
#                                                record
# 0   8372 (java) S 8061 8060 13706 34818 8060 10779...
# 1   8373 (java) R 8061 8060 13706 34818 8060 41946...
# 2   8374 (GC Thread#0) S 8061 8060 13706 34818 806...
# 3   8375 (G1 Main Marker) S 8061 8060 13706 34818 ...
# 4   8376 (G1 Conc#0) S 8061 8060 13706 34818 8060 ...
# 5   8377 (G1 Refine#0) S 8061 8060 13706 34818 806...
# 6   8378 (G1 Young RemSet) S 8061 8060 13706 34818...
# 7   8379 (VM Thread) S 8061 8060 13706 34818 8060 ...
# 8   8380 (Reference Handl) S 8061 8060 13706 34818...
# 9   8381 (Finalizer) S 8061 8060 13706 34818 8060 ...
# 10  8382 (Signal Dispatch) S 8061 8060 13706 34818...
# 11  8383 (C2 CompilerThre) R 8061 8060 13706 34818...
# 12  8384 (C1 CompilerThre) S 8061 8060 13706 34818...
# 13  8385 (Sweeper thread) S 8061 8060 13706 34818 ...
# 14  8386 (Common-Cleaner) S 8061 8060 13706 34818 ...
# 15  8390 (Service Thread) S 8061 8060 13706 34818 ...
# 16  8391 (VM Periodic Tas) S 8061 8060 13706 34818...
# 17  8392 (Honest Profiler) S 8061 8060 13706 34818...
# 18  8397 (GC Thread#1) S 8061 8060 13706 34818 806...
# 19  8398 (GC Thread#2) S 8061 8060 13706 34818 806...
#                                                record
# 0   cpu  97877922 0 8218426 1204199311 1395325 0 1...
# 1   cpu0 3611245 0 325980 28804203 8848 0 21166 0 0 0
# 2   cpu1 2549381 0 282918 29938072 6885 0 17541 0 0 0
# 3   cpu2 2816600 0 236961 29717423 6009 0 32843 0 0 0
# 4    cpu3 2602616 0 233464 29944076 5907 0 6130 0 0 0
# 5    cpu4 2478736 0 210530 30096523 4956 0 3674 0 0 0
# 6    cpu5 2323792 0 182478 30280457 4998 0 1992 0 0 0
# 7    cpu6 2362644 0 182300 30243776 4233 0 1379 0 0 0
# 8    cpu7 2272382 0 177629 30341565 3865 0 1084 0 0 0
# 9    cpu8 2273965 0 169730 30347345 4058 0 1034 0 0 0
# 10    cpu9 2297093 0 171535 30323736 3706 0 379 0 0 0
# 11  cpu10 4214994 0 454576 28097990 16784 0 698 0 0 0
# 12  cpu11 2820406 0 272958 29682243 16688 0 718 0 0 0
# 13  cpu12 2471081 0 211872 30092071 17967 0 463 0 0 0
# 14  cpu13 2360221 0 196518 30221282 16296 0 398 0 0 0
# 15  cpu14 2332106 0 193804 30252384 16976 0 362 0 0 0
# 16  cpu15 2319024 0 192232 30266501 17635 0 340 0 0 0
# 17  cpu16 2303103 0 184071 30290694 17373 0 368 0 0 0
# 18  cpu17 2421162 0 187862 30167458 18411 0 343 0 0 0
# 19  cpu18 2322261 0 185544 30272146 14987 0 430 0 0 0

# %% [markdown]
# The os trace requires four parsing steps:

# %% [markdown]
#     1) Parse the space delimited records
#     2) Compute forward difference of jiffies (which are recorded as monotonically increasing)
#     3) Align thread and system data by cpu
#     4) Normalize jiffies data

# %%
def parse_stats_record(record):
    name_length = len(record) - 52
    idx = lambda x: x + name_length

    name = ' '.join(record[1:idx(2)])[1:-1]
    state = 1 if record[idx(2)] == 'R' else 0
    jiffies = int(record[idx(13)]) + int(record[idx(14)])
    core = 1 if int(record[idx(38)]) < 20 else 2

    return [name, state, jiffies, core]

# %%
trace['os'] = trace['os'].dropna(subset = ['record'])
records = trace['os'].record.str.split(' ').map(parse_stats_record)

trace['os'].loc[:, 'os_thread'] = records.map(lambda x: x[0])
main_id = trace['tid'].set_index('thread').to_dict()['tid']['main']
trace['os'].loc[trace['os'].tid == main_id, 'os_thread'] = 'main'

trace['os'].loc[:, 'state'] = records.map(lambda x: x[1])
trace['os'].loc[:, 'jiffies'] = records.map(lambda x: x[2])
trace['os'].loc[:, 'socket'] = records.map(lambda x: x[3])
trace['os'].pop('record')

trace['os'].jiffies = trace['os'].groupby('tid').jiffies.diff().fillna(0).astype(int)

# %%
trace['sys'] = trace['sys'].record[trace['sys'].record.str.contains(r'cpu\d+')]

trace['sys'] = trace['sys'].str.replace('  ', ' ')
trace['sys'] = trace['sys'].str.split(' ')
trace['sys'] = trace['sys'].values.tolist()
trace['sys'] = pd.DataFrame(trace['sys'], columns = ['core'] + ['jiffies{}'.format(i) for i in range(len(trace['sys'][0]) - 1)], dtype = int)

trace['sys'].core = trace['sys'].core.str.replace('cpu', '')
trace['sys'] = trace['sys'].astype(int)
trace['sys']['socket'] = trace['sys'].core.map(lambda c: 1 if c < 20 else 2)
trace['sys'].pop('jiffies3')

trace['sys']['jiffies'] = trace['sys'][[col for col in trace['sys'].columns if 'core' not in col]].sum(axis = 1).astype(int)

cores = len(trace['sys'].core.unique())
epochs = trace['os'].epoch.unique()
epochs = [cores * [epoch] for epoch in epochs]
trace['sys']['epoch'] = [e for epoch in epochs for e in epoch][:len(trace['sys'])]

trace['sys'] = trace['sys'].groupby(['epoch', 'socket'])['jiffies'].sum().reset_index()
trace['sys'].jiffies = trace['sys'].groupby(['socket']).jiffies.diff().fillna(0).astype(int)

# %%
display(trace['os'].head(20))
display(trace['sys'].head(20))
# Out:
#     epoch   tid      timestamp        os_thread  state  jiffies  socket
# 0       4  8372  1565621927798             java      0        0       2
# 1       4  8373  1565621927798             main      1        0       2
# 2       4  8374  1565621927798      GC Thread#0      0        0       2
# 3       4  8375  1565621927798   G1 Main Marker      0        0       2
# 4       4  8376  1565621927798        G1 Conc#0      0        0       2
# 5       4  8377  1565621927798      G1 Refine#0      0        0       2
# 6       4  8378  1565621927798  G1 Young RemSet      0        0       1
# 7       4  8379  1565621927798        VM Thread      0        0       1
# 8       4  8380  1565621927798  Reference Handl      0        0       1
# 9       4  8381  1565621927798        Finalizer      0        0       2
# 10      4  8382  1565621927798  Signal Dispatch      0        0       2
# 11      4  8383  1565621927798  C2 CompilerThre      1        0       2
# 12      4  8384  1565621927798  C1 CompilerThre      0        0       2
# 13      4  8385  1565621927798   Sweeper thread      0        0       1
# 14      4  8386  1565621927798   Common-Cleaner      0        0       1
# 15      4  8390  1565621927798   Service Thread      0        0       1
# 16      4  8391  1565621927798  VM Periodic Tas      0        0       2
# 17      4  8392  1565621927798  Honest Profiler      0        0       2
# 18      4  8397  1565621927798      GC Thread#1      0        0       2
# 19      4  8398  1565621927798      GC Thread#2      0        0       2
#     epoch  socket  jiffies
# 0       4       1        0
# 1       4       2        0
# 2       8       1        0
# 3       8       2        2
# 4      12       1        1
# 5      12       2        0
# 6      16       1        0
# 7      16       2        1
# 8      20       1        1
# 9      20       2        0
# 10     24       1        0
# 11     24       2        2
# 12     28       1        1
# 13     28       2        1
# 14     32       1        0
# 15     32       2        0
# 16     36       1        1
# 17     36       2        0
# 18     40       1        0
# 19     40       2        2

# %% [markdown]
# To align the application and system records, we need to smooth out the data. Jiffies are updated by a timer, which is unique for each system component. Since our sampling rate is not aware of the timer, we can't claim a one-to-one mapping. We scan for the first record that satisfies
#
# $j_{sys}(t) \geq j_{app}(t) \cap j_{sys}(t) > 0$
#
# and accumulate all previous records to compute application jiffies consumption for all epochs in that group. We continue to step forward until are records are scanned.

# %%
df = pd.merge(
    trace['os'].groupby(['epoch', 'socket'])[['jiffies']].sum(),
    trace['sys'],
    on = ['epoch', 'socket'],
    suffixes = ('_app', '_sys')
).set_index(['epoch', 'socket'])

# %%
dfs = []
for socket, g in df.reset_index().groupby('socket'):
    g = g.sort_values('epoch')
    
    A = S = curr = 0
    idx = []
    vals = []
    j = g[['epoch', 'jiffies_app', 'jiffies_sys']].values
    for i, a, s in j:
        if a > 0 and A + a <= S + s:
            idx.append(i)
            vals.append([A + a, S + s])
            A = S = 0
        else:
            A += a
            S += s
    j = pd.DataFrame(index = idx, data = vals, columns = ['j_app', 'j_sys'])
    j.index.name = 'epoch'
    j['jiffies'] = j.j_app / j.j_sys
    g = pd.concat([g.set_index('epoch'), j], axis = 1).bfill().fillna(0).reset_index().set_index(['epoch', 'socket'])
    dfs.append(g)
j = pd.concat(dfs)[['jiffies']].sort_index()

# %%
trace['os'] = pd.merge(trace['os'], j, on = ['epoch', 'socket'], how = 'left', suffixes = ('_raw', '')).drop(columns = 'jiffies_raw')

# %%
sys.exi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5cae6bd5accf> in <module>
# ----> 1 sys.exi
#
# NameError: name 'sys' is not defined

# %%
tid_mapped = pd.merge(trace['vm'][trace['vm'].tid > 0], trace['os'], on = ['epoch', 'tid'], suffixes = ('', '_'))[['epoch', 'thread', 'id', 'tid', 'state', 'jiffies']]

# %%
name_mapped = pd.merge(trace['os'][~trace['os'].os_thread.isin(tid_mapped.thread.unique())], trace['vm'][~trace['vm'].thread.isin(tid_mapped.thread.unique())], on = ['epoch', 'os_thread'], how = 'left', suffixes = ('', '_'))#
name_mapped.thread = name_mapped.thread.fillna(name_mapped.os_thread)
name_mapped.state = name_mapped.state.fillna(name_mapped.state_)
name_mapped.id = name_mapped.id.fillna(-1)
name_mapped = name_mapped[['epoch', 'timestamp', 'thread', 'id', 'tid', 'state', 'jiffies']]

# %%
d = trace['vm'][['epoch', 'timestamp']].drop_duplicates().set_index('epoch').to_dict()['timestamp']

# %%
df = pd.concat([tid_mapped, name_mapped])
df.timestamp = df.epoch.apply(lambda x: d[x])
df = df.set_index(['epoch', 'thread'])
df.state = df.state.astype(float) / (df.groupby('epoch').state.sum())
df = df.reset_index().set_index('epoch')

# %%
trace['energy']
# Out:
#        epoch  socket        package          dram
# 0          1       1  133832.796143  64344.014400
# 1          1       2   32478.994873  35307.991095
# 2          2       1  133832.843506  64344.022500
# 3          2       2   32479.024170  35307.997335
# 4          3       1  133832.870117  64344.026520
# 5          3       2   32479.084839  35308.007715
# 6          4       1  133832.948120  64344.038400
# 7          4       2   32479.147644  35308.018095
# 8          5       1  133832.948120  64344.038400
# 9          5       2   32479.177795  35308.023285
# 10         6       1  133832.973206  64344.042420
# 11         6       2   32479.207275  35308.027410
# 12         7       1  133832.998718  64344.046305
# 13         7       2   32479.242371  35308.031490
# 14         8       1  133833.077026  64344.058050
# 15         8       2   32479.340576  35308.044840
# 16         9       1  133833.077026  64344.058050
# 17         9       2   32479.340576  35308.044840
# 18        10       1  133833.103333  64344.062070
# 19        10       2   32479.371765  35308.048980
# 20        11       1  133833.128235  64344.066000
# 21        11       2   32479.404053  35308.053090
# 22        12       1  133833.205811  64344.081090
# 23        12       2   32479.467773  35308.057170
# 24        13       1  133833.205811  64344.081090
# 25        13       2   32479.496277  35308.061310
# 26        14       1  133833.231934  64344.084930
# 27        14       2   32479.528320  35308.065390
# 28        15       1  133833.257202  64344.088770
# 29        15       2   32479.557190  35308.069530
# ...      ...     ...            ...           ...
# 38202  19102       1  134468.257629     14.969070
# 38203  19102       2   33121.876282  35410.710240
# 38204  19103       1  134468.282837     14.973150
# 38205  19103       2   33121.902405  35410.714380
# 38206  19104       1  134468.334290     14.981190
# 38207  19104       2   33121.955505  35410.722660
# 38208  19105       1  134468.334290     14.981190
# 38209  19105       2   33121.955505  35410.722660
# 38210  19106       1  134468.387329     14.989290
# 38211  19106       2   33122.007263  35410.730880
# 38212  19107       1  134468.412903     14.993310
# 38213  19107       2   33122.032166  35410.735020
# 38214  19108       1  134468.466492     15.001410
# 38215  19108       2   33122.086914  35410.743300
# 38216  19109       1  134468.493103     15.005490
# 38217  19109       2   33122.086914  35410.743300
# 38218  19110       1  134468.520447     15.009510
# 38219  19110       2   33122.138306  35410.751565
# 38220  19111       1  134468.544678     15.013590
# 38221  19111       2   33122.164612  35410.755705
# 38222  19112       1  134468.594421     15.021750
# 38223  19112       2   33122.216736  35410.763985
# 38224  19113       1  134468.594421     15.021750
# 38225  19113       2   33122.216736  35410.763985
# 38226  19114       1  134468.648865     15.029790
# 38227  19114       2   33122.244263  35410.768125
# 38228  19115       1  134468.672363     15.033870
# 38229  19115       2   33122.298157  35410.776375
# 38230  19116       1  134468.722717     15.042030
# 38231  19116       2   33122.351624  35410.784655
#
# [38232 rows x 4 columns]

# %%
pd.concat([df, trace['energy'].set_index('epoch')], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-59-3f62860084ad> in <module>
# ----> 1 pd.concat([df, trace['energy'].set_index('epoch')], axis = 1)
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     376         self.copy = copy
#     377
# --> 378         self.new_axes = self._get_new_axes()
#     379
#     380     def get_result(self):
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\concat.py in _get_new_axes(self)
#     443                 if i == self.axis:
#     444                     continue
# --> 445                 new_axes[i] = self._get_comb_axis(i)
#     446         else:
#     447             if len(self.join_axes) != ndim - 1:
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\concat.py in _get_comb_axis(self, i)
#     464             return _get_objs_combined_axis(self.objs, axis=data_axis,
#     465                                            intersect=self.intersect,
# --> 466                                            sort=self.sort)
#     467         except IndexError:
#     468             types = [type(x).__name__ for x in self.objs]
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\api.py in _get_objs_combined_axis(objs, intersect, axis, sort)
#      52                  if hasattr(obj, '_get_axis')]
#      53     if obs_idxes:
# ---> 54         return _get_combined_index(obs_idxes, intersect=intersect, sort=sort)
#      55
#      56
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\api.py in _get_combined_index(indexes, intersect, sort)
#      67             index = index.intersection(other)
#      68     else:
# ---> 69         index = _union_indexes(indexes, sort=sort)
#      70         index = _ensure_index(index)
#      71
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\api.py in _union_indexes(indexes, sort)
#     105         else:
#     106             for other in indexes[1:]:
# --> 107                 result = result.union(other)
#     108             return result
#     109     elif kind == 'array':
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in union(self, other)
#    2781                 result.extend([x for x in rvals if x not in value_set])
#    2782         else:
# -> 2783             indexer = self.get_indexer(other)
#    2784             indexer, = (indexer == -1).nonzero()
#    2785
#
# c:\users\atpov\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3242
#    3243         if not self.is_unique:
# -> 3244             raise InvalidIndexError('Reindexing only valid with uniquely'
#    3245                                     ' valued Index objects')
#    3246
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %% [markdown]
# ENERGY

# %% [markdown]
# Now that both the vm and os data have been fully processed, we can align them along epoch and backfill the

# %%
pd.concat(vm, j)

# %% [markdown]
# # BELOW NEEDS TO BE REVISED PENDING ABOVE #

# %%
import random

import pandas as pd
import numpy as np

max_epoch = 20

vm_trace = pd.DataFrame(index = list(range(1, max_epoch)), data = [random.random() for i in range(1, max_epoch)], columns = ['vm_state'])
os_trace = pd.DataFrame(index = list(range(1, max_epoch, 2)), data = [random.random() for i in range(1, max_epoch, 2)], columns = ['os_state'])
nrg_trace = pd.DataFrame(index = list(range(1, max_epoch, 3)), data = [10 * random.random() for i in range(1, max_epoch, 3)], columns = ['energy'])
mthd_trace = pd.DataFrame(index = list(range(1, max_epoch, 5)), data = [chr(random.randint(0, 25) + 65) for i in range(1, max_epoch, 5)], columns = ['stack_trace'])

display(vm_trace)
display(os_trace)
display(nrg_trace)
display(mthd_trace)

# %% [markdown]
# In order to attribute energy to a method, we need to align all records along a shared timestamp axis. However, since the traces are not guaranteed to share timestamps, there will be holes that need to be filled:

# %%
aligned_trace = pd.concat([vm_trace, os_trace, nrg_trace, mthd_trace], axis = 1)
aligned_trace

# %% [markdown]
# In the principled attribution model we discussed early today, we need to find the first timestamp such that all 4 values have changed. The question is how do we fill holes in the data.
#
# I propose what we can do is the following:
#
# 1) Back fill all values

# %%
trace = aligned_trace.bfill()
trace

# %% [markdown]
# 2) Find the longest stretch of identical values over time adjacent records

# %%
matches = dict(zip(aligned_trace.columns, [False] * 4))
i = 0
g = 0
group_id = []
for _ in range(100):
    if len(trace) == 0:
        break
    i += 1
    record = (trace != trace.shift(-i)).head(1).to_dict('record')[0]
    matches = {key: matches[key] | record[key] for key in matches}
    if sum(int(val) for val in matches.values()) == len(trace.columns):
        g += 1
        subtrace = trace.head(i)
        subtrace.loc[:, 'group'] = g
        group_id.append(subtrace['group'])
        trace = trace.tail(len(trace) - i)
        matches = dict(zip(aligned_trace.columns, [False] * 4))
        i = 0

group_id = pd.concat(group_id)
trace = pd.concat([aligned_trace, group_id.astype(int)], axis = 1)
trace

# %% [markdown]
# Now we need to settle on an attribution method for the values of each group, which I believe is where we got stuck. In this example, the timestamps are evenly spaced, so we could aggregate:

# %%
df = trace.groupby('group').agg({'vm_state': 'mean', 'os_state': 'mean', 'energy': 'sum', 'stack_trace': set})
df.energy *= df.os_state * df.vm_state
df.stack_trace = df.stack_trace.map(lambda a: {x for x in a if x == x})
df.stack_trace = df.stack_trace.map(lambda x: list(x)[0] if len(x) > 0 else 'end')
df.index = df.index.astype(int)
df[['energy', 'stack_trace']]

# %%
max_epoch = 1000

vm_trace = pd.DataFrame(index = list(range(1, max_epoch)), data = [random.random() for i in range(1, max_epoch)], columns = ['vm_state'])
os_trace = pd.DataFrame(index = list(range(1, max_epoch)), data = [random.random() for i in range(1, max_epoch)], columns = ['os_state'])
nrg_trace = pd.DataFrame(index = list(range(1, max_epoch)), data = [10 * random.random() for i in range(1, max_epoch)], columns = ['energy'])
mthd_trace = pd.DataFrame(index = list(range(1, max_epoch)), data = [chr(random.randint(0, 25) + 65) for i in range(1, max_epoch)], columns = ['stack_trace'])

aligned_trace = pd.concat([vm_trace, os_trace, nrg_trace, mthd_trace], axis = 1)
for col in aligned_trace.columns:
    aligned_trace.loc[aligned_trace.index.isin(np.random.randint(0, 1000, 300)), col] = np.nan
    
aligned_trace

# %%
trace = aligned_trace.bfill()
trace

matches = dict(zip(aligned_trace.columns, [False] * 4))
i = 0
g = 0
group_id = []
for _ in range(100):
    if len(trace) == 0:
        break
    i += 1
    record = (trace != trace.shift(-i)).head(1).to_dict('record')[0]
    matches = {key: matches[key] | record[key] for key in matches}
    if sum(int(val) for val in matches.values()) == len(trace.columns):
        g += 1
        subtrace = trace.head(i)
        subtrace.loc[:, 'group'] = g
        group_id.append(subtrace['group'])
        trace = trace.tail(len(trace) - i)
        matches = dict(zip(aligned_trace.columns, [False] * 4))
        i = 0

group_id = pd.concat(group_id)
trace = pd.concat([aligned_trace, group_id.astype(int)], axis = 1)
trace

df = trace.groupby('group').agg({'vm_state': 'mean', 'os_state': 'mean', 'energy': 'sum', 'stack_trace': set})
df.energy *= df.os_state * df.vm_state
df.stack_trace = df.stack_trace.map(lambda a: {x for x in a if x == x})
df.stack_trace = df.stack_trace.map(lambda x: list(x)[0] if len(x) > 0 else 'end')
df.index = df.index.astype(int)
df[['energy', 'stack_trace']]
